# %% [markdown]
# ### OS:
#  The OS module in Python provides a way of using operating system dependent functionality.
# ### IO:
#  in Python 3.x it is the default interface to access files and streams.

# %%
import os
import io

# %%
import numpy as np
from pandas import DataFrame

# %% [markdown]
# ### Count Vectorizer
# Converts a collection of text documents to a matrix of token counts
#
# This implementation produces a sparse representation of the counts using scipy.sparse.csr_matrix.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ### Multinomial Naive Bayes:
# Parameter estimation and event models. ... The assumptions on distributions of features are called the event model of the Naive Bayes classifier. For discrete features like the ones encountered in document classification (include spam filtering), multinomial and Bernoulli distributions are popular.

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
def readFiles(path):
    for root, dirnames, filenames in os.walk(path):
        for filename in filenames:
            path = os.path.join(root, filename)
            
            inBody = False
            lines = []
            f = io.open(path, 'r', encoding='latin1')
            
            for line in f:
                if inBody:
                    lines.append(line)
                elif line == '\n': # it finds the first empty line and we suppose everything under that empty line is body.
                    inBody=True
            f.close()
            message = '\n'.join(lines)
            yield path, message

# %% [markdown]
# ### good explanation about "yield"
# https://stackoverflow.com/questions/231767/what-does-the-yield-keyword-do

# %% [markdown]
# ### example of os.walk()

# %%
for root, dirs, files in os.walk(".", topdown=False):
   for name in files:
      print(os.path.join(root, name))
   for name in dirs:
      print(os.path.join(root, name))
# Out:
# .\.ipynb_checkpoints\Implementing a Spam Classifier with  Naive Bayes-checkpoint.ipynb
# .\Implementing a Spam Classifier with  Naive Bayes.ipynb
# .\.ipynb_checkpoints

# %%
def dataFrameFromDirectory(path, classification):
    rows=[]
    index=[]
    for filename, message in readFiles(path):
        rows.append({'message':message, 'class':classification})
        index.append(filename)
    return DataFrame(rows, index=index)

# %%
data = DataFrame({'message':[], 'class':[]})
data = data.append(dataFrameFromDirectory('C:\\Users\\mojiway\\Desktop\\tutorials\\data-science-frank-kane-udemy\\my-files-data-science-udemy-frank-kane\\DataScience-Python3\\emails\\spam', 'spam'))
data = data.append(dataFrameFromDirectory('C:\\Users\\mojiway\\Desktop\\tutorials\\data-science-frank-kane-udemy\\my-files-data-science-udemy-frank-kane\\DataScience-Python3\\emails\\ham', 'ham'))

# %%
data
# Out:
#                                                    class  \
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# C:\Users\mojiway\Desktop\tutorials\data-science...  spam
# ...                                                  ...
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
# C:\Users\mojiway\Desktop\tutorials\data-science...   ham
#
#                                                                                               message
# C:\Users\mojiway\Desktop\tutorials\data-science...  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Tr...
# C:\Users\mojiway\Desktop\tutorials\data-science...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# C:\Users\mojiway\Desktop\tutorials\data-science...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# C:\Users\mojiway\Desktop\tutorials\data-science...  ##############################################...
# C:\Users\mojiway\Desktop\tutorials\data-science...  I thought you might like these:\n\n1) Slim Dow...
# C:\Users\mojiway\Desktop\tutorials\data-science...  A POWERHOUSE GIFTING PROGRAM You Don't Want To...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Help wanted.  We are a 14 year old fortune 500...
# C:\Users\mojiway\Desktop\tutorials\data-science...  <html>\n\n<head>\n\n<title>ReliaQuote - Save U...
# C:\Users\mojiway\Desktop\tutorials\data-science...  TIRED OF THE BULL OUT THERE?\n\nWant To Stop L...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Dear ricardo1 ,\n\n\n\n<html>\n\n<body>\n\n<ce...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Cellular Phone Accessories All At Below Wholes...
# C:\Users\mojiway\Desktop\tutorials\data-science...  <table width="600" border="20" align="center" ...
# C:\Users\mojiway\Desktop\tutorials\data-science...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# C:\Users\mojiway\Desktop\tutorials\data-science...  <HTML><HEAD><TITLE>FREE Motorola Cell Phone wi...
# C:\Users\mojiway\Desktop\tutorials\data-science...  <HTML><HEAD><TITLE>Lowest Rate Services</TITLE...
# C:\Users\mojiway\Desktop\tutorials\data-science...  \n\n\n\nWant to watch Sporting Events?--Movies...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Help wanted.  We are a 14 year old fortune 500...
# C:\Users\mojiway\Desktop\tutorials\data-science...  DEAR FRIEND,I AM MRS.  SESE-SEKO WIDOW OF LATE...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Lowest rates available for term life insurance...
# C:\Users\mojiway\Desktop\tutorials\data-science...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# C:\Users\mojiway\Desktop\tutorials\data-science...  CENTRAL BANK OF NIGERIA\n\nFOREIGN REMITTANCE ...
# C:\Users\mojiway\Desktop\tutorials\data-science...  --===_SecAtt_000_1fheucnqggtggp\n\nContent-Typ...
# C:\Users\mojiway\Desktop\tutorials\data-science...  ------=_NextPart_000_00B2_83B03D1E.C6530E24\n\...
# C:\Users\mojiway\Desktop\tutorials\data-science...  This is a multi-part message in MIME format.\n...
# C:\Users\mojiway\Desktop\tutorials\data-science...  <HTML><HEAD>\n\n<META http-equiv=3DContent-Typ...
# C:\Users\mojiway\Desktop\tutorials\data-science...  DEAR FRIEND,I AM MRS.  SESE-SEKO WIDOW OF LATE...
# C:\Users\mojiway\Desktop\tutorials\data-science...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# C:\Users\mojiway\Desktop\tutorials\data-science...  <HTML><HEAD><TITLE>MILFhunter</TITLE>\n\n<META...
# C:\Users\mojiway\Desktop\tutorials\data-science...  <html>\n\n<head>\n\n</head>\n\n<body>\n\n\n\n<...
# C:\Users\mojiway\Desktop\tutorials\data-science...  <html>\n\n\n\n<head>\n\n<meta http-equiv=3D"Co...
# ...                                                                                               ...
# C:\Users\mojiway\Desktop\tutorials\data-science...  This is possible, however using SA as a block ...
# C:\Users\mojiway\Desktop\tutorials\data-science...  \n\n--- Martin Adamson <martin@srv0.ems.ed.ac....
# C:\Users\mojiway\Desktop\tutorials\data-science...  ----- Original Message -----\n\nFrom: "Tim Cha...
# C:\Users\mojiway\Desktop\tutorials\data-science...  \n\n> Mr Tim Chapman, freelance gentleman of l...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Smith, Graham - Computing Technician wrote:\n\...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Geege wrote a strange story:\n\n>I know a guy ...
# C:\Users\mojiway\Desktop\tutorials\data-science...  \n\n[Paul Moore]\n\n>    but let's walk before...
# C:\Users\mojiway\Desktop\tutorials\data-science...  On Mon, Nov 25, 2002 at 06:54:49PM +0000, Phil...
# C:\Users\mojiway\Desktop\tutorials\data-science...  \n\nI don't know how one can expect better and...
# C:\Users\mojiway\Desktop\tutorials\data-science...  No, you need to learn how declarations work in...
# C:\Users\mojiway\Desktop\tutorials\data-science...  \n\n    Richie> As I understand it, post-1.8x ...
# C:\Users\mojiway\Desktop\tutorials\data-science...  \n\n    Paul> I suspect the best answer is to ...
# C:\Users\mojiway\Desktop\tutorials\data-science...  The Times\n\n\n\n \n\n December 04, 2002 \n\n ...
# C:\Users\mojiway\Desktop\tutorials\data-science...  I have to say I was surprised about Jacko dang...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Now then I recently read a novel about exactly...
# C:\Users\mojiway\Desktop\tutorials\data-science...  What the hell is it with these mini remote con...
# C:\Users\mojiway\Desktop\tutorials\data-science...  here, for your enjoyment, is a little somethin...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Sean O'Donnell wrote:\n\n> Doesnt answer your ...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Joe McNally writes:\n\n\n\n> What the hell is ...
# C:\Users\mojiway\Desktop\tutorials\data-science...  http://news.bbc.co.uk/1/hi/world/europe/254182...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Hi all.\n\nDoes anyone know how to set up dual...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Carlos Luna wrote:\n\n\n\n>Hi all.\n\n>Does an...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Hi all\n\n\n\n\n\nI have a prob when trying to...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Tim Chapman writes:\n\n\n\n> http://news.bbc.c...
# C:\Users\mojiway\Desktop\tutorials\data-science...  > I had the same problem when installing Win o...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Man killed 'trying to surf' on Tube train \n\n...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Hi Gianni,\n\n\n\nA very good resource for thi...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Gianni Ponzi wrote:\n\n> I have a prob when tr...
# C:\Users\mojiway\Desktop\tutorials\data-science...  Neale Pickett <neale@woozle.org> writes:\n\n\n...
# C:\Users\mojiway\Desktop\tutorials\data-science...  \n\nHi,\n\n\n\nI think you need to give us a l...
#
# [3000 rows x 2 columns]

# %% [markdown]
# ### what'a next?
#
#  we need to use countVectorizer() to go through all messages, and count all words and tell us how many times each word repeats.
#  we call that tokenizing the words. the variable "counts" here will demonstrate it. simply each message will be indicated as a list of numbers for each word's repetition.

# %%
vectorizer = CountVectorizer()
counts = vectorizer.fit_transform(data['message'].values)

# %%
# Out:
# <3000x62964 sparse matrix of type '<class 'numpy.int64'>'
# 	with 429785 stored elements in Compressed Sparse Row format>

# %% [markdown]
# now its time to use the multinomial naive bayes classifier to do the analysis

# %%
classifier = MultinomialNB()
targets = data['class'].values
classifier.fit(counts, targets)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# ## now we can try it out

# %%
examples = ['Free Viagra now!!!', "Hi Bob, how about a game of golf tomorrow?"]
example_counts = vectorizer.transform(examples)
predictions = classifier.predict(example_counts)
predictions
# Out:
# array(['spam', 'ham'], dtype='<U4')

# %% [markdown]
# ### train-test split

# %%
from sklearn.model_selection import train_test_split

# %%
X = data['message']
y = data['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
vectorizer = CountVectorizer()
counts = vectorizer.fit_transform(X_train.values)
classifier = MultinomialNB()
targets = y_train.values

# %%
classifier.fit(counts, targets)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
example_counts = vectorizer.transform(X_test)
pred = classifier.predict(example_counts)

# %%
pred
# Out:
# array(['ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'spam',
#        'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam',
#        'ham', 'ham', 'spam', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham',
#        'ham', 'ham', 'spam', 'ham', 'spam', 'spam', 'spam', 'ham', 'ham',
#        'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'spam',
#        'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'spam',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'spam', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham',
#        'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'spam', 'spam', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'spam', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam',
#        'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'spam', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'spam', 'spam', 'ham', 'spam', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'spam', 'spam', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham',
#        'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'spam', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'spam', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam',
#        'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'spam', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'spam',
#        'spam', 'ham', 'spam', 'spam', 'spam', 'ham', 'ham', 'ham', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'spam', 'ham', 'spam', 'ham', 'ham', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'spam',
#        'ham', 'ham', 'ham', 'spam', 'spam', 'spam', 'ham', 'ham', 'spam',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'spam', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam',
#        'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham',
#        'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'spam', 'ham', 'spam', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'spam', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'spam', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'spam', 'ham',
#        'ham', 'ham', 'spam', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'spam', 'spam', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'spam', 'ham', 'spam',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham',
#        'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'spam',
#        'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'spam',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'spam',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham',
#        'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham'],
#       dtype='<U4')

# %%
submission = DataFrame({
     "prediction": pred,
        "Reality": y_test
       
    })
submission.to_excel('results.xlsx', index=False)

# %%
submission
# Out:
#                                                    Reality prediction
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...    spam       spam
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...    spam       spam
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...    spam       spam
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...    spam       spam
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...    spam       spam
# C:\Users\mojiway\Desktop\tutorials\data-science...    spam       spam
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...    spam       spam
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# ...                                                    ...        ...
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
# C:\Users\mojiway\Desktop\tutorials\data-science...     ham        ham
#
# [990 rows x 2 columns]
